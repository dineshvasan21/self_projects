# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %%
from numpy.random import seed
seed(1)
import tensorflow
tensorflow.random.set_seed(10)

# %%
df =pd.read_csv("prices.csv", header=0)
display (df)
# Out:
#                        date symbol        open       close         low  \
# 0       2016-01-05 00:00:00   WLTW  123.430000  125.839996  122.309998
# 1       2016-01-06 00:00:00   WLTW  125.239998  119.980003  119.940002
# 2       2016-01-07 00:00:00   WLTW  116.379997  114.949997  114.930000
# 3       2016-01-08 00:00:00   WLTW  115.480003  116.620003  113.500000
# 4       2016-01-11 00:00:00   WLTW  117.010002  114.970001  114.089996
# ...                     ...    ...         ...         ...         ...
# 851259           2016-12-30    ZBH  103.309998  103.199997  102.849998
# 851260           2016-12-30   ZION   43.070000   43.040001   42.689999
# 851261           2016-12-30    ZTS   53.639999   53.529999   53.270000
# 851262  2016-12-30 00:00:00    AIV   44.730000   45.450001   44.410000
# 851263  2016-12-30 00:00:00    FTV   54.200001   53.630001   53.389999
#
#               high     volume
# 0       126.250000  2163600.0
# 1       125.540001  2386400.0
# 2       119.739998  2489500.0
# 3       117.440002  2006300.0
# 4       117.330002  1408600.0
# ...            ...        ...
# 851259  103.930000   973800.0
# 851260   43.310001  1938100.0
# 851261   53.740002  1701200.0
# 851262   45.590000  1380900.0
# 851263   54.480000   705100.0
#
# [851264 rows x 7 columns]

# %%
print(df.shape)
# Out:
# (851264, 7)

# %%
print(df.columns)
# Out:
# Index(['date', 'symbol', 'open', 'close', 'low', 'high', 'volume'], dtype='object')

# %%
df.symbol.value_counts()
# Out:
# KSU     1762
# NOC     1762
# ORCL    1762
# OMC     1762
# OKE     1762
#         ...
# KHC      378
# HPE      304
# CSRA     284
# WLTW     251
# FTV      126
# Name: symbol, Length: 501, dtype: int64

# %%
df.symbol.unique()
# Out:
# array(['WLTW', 'A', 'AAL', 'AAP', 'AAPL', 'ABC', 'ABT', 'ACN', 'ADBE',
#        'ADI', 'ADM', 'ADP', 'ADS', 'ADSK', 'AEE', 'AEP', 'AES', 'AET',
#        'AFL', 'AGN', 'AIG', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALK', 'ALL',
#        'ALXN', 'AMAT', 'AME', 'AMG', 'AMGN', 'AMP', 'AMT', 'AMZN', 'AN',
#        'ANTM', 'AON', 'APA', 'APC', 'APD', 'APH', 'ARNC', 'ATVI', 'AVB',
#        'AVGO', 'AVY', 'AWK', 'AXP', 'AYI', 'AZO', 'BA', 'BAC', 'BAX',
#        'BBBY', 'BBT', 'BBY', 'BCR', 'BDX', 'BEN', 'BHI', 'BIIB', 'BK',
#        'BLK', 'BLL', 'BMY', 'BSX', 'BWA', 'BXP', 'C', 'CA', 'CAG', 'CAH',
#        'CAT', 'CB', 'CBG', 'CBS', 'CCI', 'CCL', 'CELG', 'CERN', 'CF',
#        'CHD', 'CHK', 'CHRW', 'CI', 'CINF', 'CL', 'CLX', 'CMA', 'CMCSA',
#        'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COF', 'COG', 'COH',
#        'COL', 'COO', 'COP', 'COST', 'CPB', 'CRM', 'CSCO', 'CSX', 'CTAS',
#        'CTL', 'CTSH', 'CTXS', 'CVS', 'CVX', 'CXO', 'D', 'DAL', 'DD', 'DE',
#        'DFS', 'DG', 'DGX', 'DHI', 'DHR', 'DIS', 'DISCA', 'DISCK', 'DLR',
#        'DLTR', 'DNB', 'DOV', 'DOW', 'DPS', 'DRI', 'DTE', 'DUK', 'DVA',
#        'DVN', 'EA', 'EBAY', 'ECL', 'ED', 'EFX', 'EIX', 'EL', 'EMN', 'EMR',
#        'ENDP', 'EOG', 'EQIX', 'EQR', 'EQT', 'ES', 'ESRX', 'ESS', 'ETFC',
#        'ETN', 'ETR', 'EW', 'EXC', 'EXPD', 'EXPE', 'EXR', 'F', 'FAST',
#        'FCX', 'FDX', 'FE', 'FFIV', 'FIS', 'FISV', 'FITB', 'FL', 'FLIR',
#        'FLR', 'FLS', 'FMC', 'FOX', 'FOXA', 'FRT', 'FSLR', 'FTI', 'FTR',
#        'GD', 'GE', 'GGP', 'GILD', 'GIS', 'GLW', 'GOOG', 'GOOGL', 'GPC',
#        'GPN', 'GPS', 'GRMN', 'GS', 'GT', 'GWW', 'HAL', 'HAR', 'HAS',
#        'HBAN', 'HBI', 'HCN', 'HCP', 'HD', 'HES', 'HIG', 'HOG', 'HOLX',
#        'HON', 'HP', 'HPQ', 'HRB', 'HRL', 'HRS', 'HSIC', 'HST', 'HSY',
#        'HUM', 'IBM', 'ICE', 'IDXX', 'IFF', 'ILMN', 'INTC', 'INTU', 'IP',
#        'IPG', 'IR', 'IRM', 'ISRG', 'ITW', 'IVZ', 'JBHT', 'JCI', 'JEC',
#        'JNJ', 'JNPR', 'JPM', 'JWN', 'K', 'KEY', 'KIM', 'KLAC', 'KMB',
#        'KMX', 'KO', 'KR', 'KSS', 'KSU', 'L', 'LB', 'LEG', 'LEN', 'LH',
#        'LKQ', 'LLL', 'LLTC', 'LLY', 'LMT', 'LNC', 'LNT', 'LOW', 'LRCX',
#        'LUK', 'LUV', 'LVLT', 'M', 'MA', 'MAA', 'MAC', 'MAR', 'MAS', 'MAT',
#        'MCD', 'MCHP', 'MCK', 'MCO', 'MDLZ', 'MDT', 'MET', 'MHK', 'MJN',
#        'MKC', 'MLM', 'MMC', 'MMM', 'MNST', 'MO', 'MON', 'MOS', 'MRK',
#        'MRO', 'MSFT', 'MSI', 'MTB', 'MTD', 'MU', 'MUR', 'MYL', 'NBL',
#        'NDAQ', 'NEE', 'NEM', 'NFLX', 'NFX', 'NI', 'NKE', 'NOC', 'NOV',
#        'NRG', 'NSC', 'NTAP', 'NTRS', 'NUE', 'NVDA', 'NWL', 'O', 'OKE',
#        'OMC', 'ORCL', 'ORLY', 'OXY', 'PAYX', 'PBCT', 'PBI', 'PCAR', 'PCG',
#        'PCLN', 'PDCO', 'PEG', 'PEP', 'PFE', 'PFG', 'PG', 'PGR', 'PH',
#        'PHM', 'PKI', 'PLD', 'PM', 'PNC', 'PNR', 'PNW', 'PPG', 'PPL',
#        'PRGO', 'PRU', 'PSA', 'PVH', 'PWR', 'PX', 'PXD', 'QCOM', 'R',
#        'RAI', 'RCL', 'REGN', 'RF', 'RHI', 'RHT', 'RIG', 'RL', 'ROK',
#        'ROP', 'ROST', 'RRC', 'RSG', 'RTN', 'SBUX', 'SCG', 'SCHW', 'SE',
#        'SEE', 'SHW', 'SIG', 'SJM', 'SLB', 'SLG', 'SNA', 'SNI', 'SO',
#        'SPG', 'SPGI', 'SPLS', 'SRCL', 'SRE', 'STI', 'STT', 'STX', 'STZ',
#        'SWK', 'SWKS', 'SWN', 'SYK', 'SYMC', 'SYY', 'T', 'TAP', 'TDC',
#        'TEL', 'TGNA', 'TGT', 'TIF', 'TJX', 'TMK', 'TMO', 'TROW', 'TRV',
#        'TSCO', 'TSN', 'TSO', 'TSS', 'TWX', 'TXN', 'TXT', 'UAA', 'UAL',
#        'UDR', 'UHS', 'ULTA', 'UNH', 'UNM', 'UNP', 'UPS', 'URBN', 'URI',
#        'USB', 'UTX', 'V', 'VAR', 'VFC', 'VIAB', 'VLO', 'VMC', 'VNO',
#        'VRSK', 'VRSN', 'VRTX', 'VTR', 'VZ', 'WAT', 'WBA', 'WDC', 'WEC',
#        'WFC', 'WFM', 'WHR', 'WM', 'WMB', 'WMT', 'WU', 'WY', 'WYN', 'WYNN',
#        'XEC', 'XEL', 'XL', 'XLNX', 'XOM', 'XRAY', 'XRX', 'YHOO', 'YUM',
#        'ZBH', 'ZION', 'AIV', 'CHTR', 'LYB', 'GM', 'ABBV', 'DLPH', 'FB',
#        'FBHS', 'HCA', 'KMI', 'KORS', 'MPC', 'NLSN', 'PSX', 'TDG', 'TRIP',
#        'XYL', 'ZTS', 'COTY', 'MNK', 'NWS', 'NWSA', 'EVHC', 'ALLE', 'CFG',
#        'NAVI', 'QRVO', 'SYF', 'WRK', 'KHC', 'PYPL', 'HPE', 'CSRA', 'FTV'],
#       dtype=object)

# %%
display(df.symbol.unique().shape)
# Out:
# (501,)

# %%
df.symbol.unique()[0:20]
# Out:
# array(['WLTW', 'A', 'AAL', 'AAP', 'AAPL', 'ABC', 'ABT', 'ACN', 'ADBE',
#        'ADI', 'ADM', 'ADP', 'ADS', 'ADSK', 'AEE', 'AEP', 'AES', 'AET',
#        'AFL', 'AGN'], dtype=object)

# %%
print(len(df.symbol.values))
# Out:
# 851264

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851264 entries, 0 to 851263
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    851264 non-null  object
#  1   symbol  851264 non-null  object
#  2   open    851264 non-null  float64
#  3   close   851264 non-null  float64
#  4   low     851264 non-null  float64
#  5   high    851264 non-null  float64
#  6   volume  851264 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 45.5+ MB

# %%
df.describe()
# Out:
#                 open          close            low           high  \
# count  851264.000000  851264.000000  851264.000000  851264.000000
# mean       70.836986      70.857109      70.118414      71.543476
# std        83.695876      83.689686      82.877294      84.465504
# min         0.850000       0.860000       0.830000       0.880000
# 25%        33.840000      33.849998      33.480000      34.189999
# 50%        52.770000      52.799999      52.230000      53.310001
# 75%        79.879997      79.889999      79.110001      80.610001
# max      1584.439941    1578.130005    1549.939941    1600.930054
#
#              volume
# count  8.512640e+05
# mean   5.415113e+06
# std    1.249468e+07
# min    0.000000e+00
# 25%    1.221500e+06
# 50%    2.476250e+06
# 75%    5.222500e+06
# max    8.596434e+08

# %%
df.isnull().sum()
# Out:
# date      0
# symbol    0
# open      0
# close     0
# low       0
# high      0
# volume    0
# dtype: int64

# %%
df.date.unique()
# Out:
# array(['2016-01-05 00:00:00', '2016-01-06 00:00:00',
#        '2016-01-07 00:00:00', ..., '2016-12-28', '2016-12-29',
#        '2016-12-30'], dtype=object)

# %%
pd.DataFrame(df.date.unique())
# Out:
#                         0
# 0     2016-01-05 00:00:00
# 1     2016-01-06 00:00:00
# 2     2016-01-07 00:00:00
# 3     2016-01-08 00:00:00
# 4     2016-01-11 00:00:00
# ...                   ...
# 3519           2016-12-23
# 3520           2016-12-27
# 3521           2016-12-28
# 3522           2016-12-29
# 3523           2016-12-30
#
# [3524 rows x 1 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Calling the file in nyse named securities.csv, It has the company details
comp_info = pd.read_csv('securities.csv')
comp_info
# Out:
#     Ticker symbol                Security SEC filings             GICS Sector  \
# 0             MMM              3M Company     reports             Industrials
# 1             ABT     Abbott Laboratories     reports             Health Care
# 2            ABBV                  AbbVie     reports             Health Care
# 3             ACN           Accenture plc     reports  Information Technology
# 4            ATVI     Activision Blizzard     reports  Information Technology
# ..            ...                     ...         ...                     ...
# 500          YHOO              Yahoo Inc.     reports  Information Technology
# 501           YUM         Yum! Brands Inc     reports  Consumer Discretionary
# 502           ZBH  Zimmer Biomet Holdings     reports             Health Care
# 503          ZION           Zions Bancorp     reports              Financials
# 504           ZTS                  Zoetis     reports             Health Care
#
#                   GICS Sub Industry   Address of Headquarters  \
# 0          Industrial Conglomerates       St. Paul, Minnesota
# 1             Health Care Equipment   North Chicago, Illinois
# 2                   Pharmaceuticals   North Chicago, Illinois
# 3    IT Consulting & Other Services           Dublin, Ireland
# 4       Home Entertainment Software  Santa Monica, California
# ..                              ...                       ...
# 500    Internet Software & Services     Sunnyvale, California
# 501                     Restaurants      Louisville, Kentucky
# 502           Health Care Equipment           Warsaw, Indiana
# 503                  Regional Banks      Salt Lake City, Utah
# 504                 Pharmaceuticals  Florham Park, New Jersey
#
#     Date first added      CIK
# 0                NaN    66740
# 1         31-03-1964     1800
# 2         31-12-2012  1551152
# 3         06-07-2011  1467373
# 4         31-08-2015   718877
# ..               ...      ...
# 500              NaN  1011006
# 501       06-10-1997  1041061
# 502              NaN  1136869
# 503              NaN   109380
# 504       21-06-2013  1555280
#
# [505 rows x 8 columns]

# %%
comp_info["Ticker symbol"].nunique()
# Out:
# 505

# %%
comp_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Ticker symbol            505 non-null    object
#  1   Security                 505 non-null    object
#  2   SEC filings              505 non-null    object
#  3   GICS Sector              505 non-null    object
#  4   GICS Sub Industry        505 non-null    object
#  5   Address of Headquarters  505 non-null    object
#  6   Date first added         307 non-null    object
#  7   CIK                      505 non-null    int64
# dtypes: int64(1), object(7)
# memory usage: 31.7+ KB

# %%
comp_info.isnull().sum()
# Out:
# Ticker symbol                0
# Security                     0
# SEC filings                  0
# GICS Sector                  0
# GICS Sub Industry            0
# Address of Headquarters      0
# Date first added           198
# CIK                          0
# dtype: int64

# %%
comp_info.describe()
# Out:
#                 CIK
# count  5.050000e+02
# mean   7.074490e+05
# std    5.144375e+05
# min    1.800000e+03
# 25%    8.631200e+04
# 50%    8.310010e+05
# 75%    1.075531e+06
# max    1.659166e+06

# %%
comp_info.loc[comp_info.Security.str.startswith('Face') , :]
# Out:
#     Ticker symbol  Security SEC filings             GICS Sector  \
# 181            FB  Facebook     reports  Information Technology
#
#                 GICS Sub Industry Address of Headquarters Date first added  \
# 181  Internet Software & Services  Menlo Park, California       23-12-2013
#
#          CIK
# 181  1326801

# %%
comp_info.loc[comp_info.Security.str.startswith('Acc') , :]
# Out:
#   Ticker symbol       Security SEC filings             GICS Sector  \
# 3           ACN  Accenture plc     reports  Information Technology
#
#                 GICS Sub Industry Address of Headquarters Date first added  \
# 3  IT Consulting & Other Services         Dublin, Ireland       06-07-2011
#
#        CIK
# 3  1467373

# %%
comp_plot = comp_info.loc[(comp_info["Security"] == 'Yahoo Inc.') | (comp_info["Security"] == 'Xerox Corp.') | (comp_info["Security"] == 'Adobe Systems Inc')
              | (comp_info["Security"] == 'Microsoft Corp.') | (comp_info["Security"] == 'Adobe Systems Inc')
              | (comp_info["Security"] == 'Facebook') | (comp_info["Security"] == 'Goldman Sachs Group') , ["Ticker symbol"] ]["Ticker symbol"]
print(comp_plot)
# Out:
# 6      ADBE
# 181      FB
# 212      GS
# 306    MSFT
# 496     XRX
# 500    YHOO
# Name: Ticker symbol, dtype: object

# %%
for i in comp_plot:
    print (i)
# Out:
# ADBE
# FB
# GS
# MSFT
# XRX
# YHOO

# %%
def plotter(code):
    # Function used to create graphs for 6 companies
    global closing_stock ,opening_stock
    #creating plot of all 6 company for opening and closing stock  total 12 graphs
    # Below statement create 2X2 empty chart
    f, axs = plt.subplots(2,2,figsize=(15,8))
    # total 12 graphs
    # creating plot opening prize of particular company
    plt.subplot(212)
    #taking name of the company as code, get all records related to one company
    company = df[df['symbol']==code]
    #taking the values of one company and taking its open column values to 1D array
    company = company.open.values.astype('float32')
    #reshaping the open stock value from 1D  to 2D .
    company = company.reshape(-1, 1)
    # putting the value of company in opening_stock
    opening_stock = company
    # plotting the data with green graph between "Time" and "prices vs time"

    plt.grid(True)# enalbling the grid in graph
    plt.xlabel('Time') # setting X axis as time
    # setting Y axis as company name + open stock prices
    plt.ylabel(code + " open stock prices")
    plt.title('prices Vs Time') # setting title
    plt.plot(company , 'g') # calling the graph with green graph line

    # creating plot closing prize of particular company
    plt.subplot(211)
    #taking name of the company as code
    company_close = df[df['symbol']==code]
    #taking the values of one company and taking its close column values
    company_close = company_close.close.values.astype('float32')
    #reshaping the open column value in 1D and calling it closing_stock
   # -1 for unknown dimension
    company_close = company_close.reshape(-1, 1)
    # putting company_close value in closing_stock
    closing_stock = company_close
    # plotting the data graph between "Time" and "prices vs time"
    plt.xlabel('Time') # setting x axis as time
    plt.ylabel(code + " close stock prices")# setting y axis as company name + open stock prices
    plt.title('prices Vs Time') # setting title as price vs time
    plt.grid(True) # enabling the grid in graph
    plt.plot(company_close , 'b') #creating the data graph in blue graph line
    plt.show() # calling the graph

# %%
for i in comp_plot:
    plotter(i)

# %%
stocks= np.array (df[df.symbol.isin (['GOOGL'])].close)
print(stocks)
# Out:
# [626.750011 623.990017 608.260035 ... 804.570007 802.880005 792.450012]

# %%
display (stocks.shape)
# Out:
# (1762,)

# %%
stocks = stocks.reshape(len(stocks) , 1)
print (stocks.shape)
print(stocks)
# Out:
# (1762, 1)
# [[626.750011]
#  [623.990017]
#  [608.260035]
#  ...
#  [804.570007]
#  [802.880005]
#  [792.450012]]

# %%
from sklearn.preprocessing import MinMaxScaler
#scaling features between 0 and 1
scaler = MinMaxScaler(feature_range=(0, 1))
stocks = scaler.fit_transform(stocks)
display (stocks)
# Out:
# array([[0.24318329],
#        [0.23966334],
#        [0.21960214],
#        ...,
#        [0.46996559],
#        [0.46781025],
#        [0.45450838]])

# %%
print (stocks.shape)
# Out:
# (1762, 1)

# %%
train = int(len(stocks) * 0.80)
print (train)
# Out:
# 1409

# %%
test = len(stocks) - train
print (test)
# Out:
# 353

# %%
train = stocks[0:train]
display (train.shape)
print(train)
# Out:
# (1409, 1)
# [[0.24318329]
#  [0.23966334]
#  [0.21960214]
#  ...
#  [0.30253792]
#  [0.29853339]
#  [0.29118738]]

# %%
test = stocks[len(train) : ]
display(test.shape)
display (test)
# Out:
# (353, 1)
# array([[0.28959319],
#        [0.3242316 ],
#        [0.32572373],
#        [0.31939806],
#        [0.32304553],
#        [0.32909067],
#        [0.32222929],
#        [0.32900138],
#        [0.31043233],
#        [0.26522132],
#        [0.23216425],
#        [0.22497127],
#        [0.28525698],
#        [0.29574037],
#        [0.28519323],
#        [0.27005486],
#        [0.246767  ],
#        [0.26634355],
#        [0.25631934],
#        [0.24600182],
#        [0.26502998],
#        [0.26443053],
#        [0.2742125 ],
#        [0.27959443],
#        [0.27598518],
#        [0.2920546 ],
#        [0.29262852],
#        [0.30047186],
#        [0.28676188],
#        [0.29449048],
#        [0.27691623],
#        [0.27703097],
#        [0.27909703],
#        [0.26027296],
#        [0.23999491],
#        [0.23790332],
#        [0.25800281],
#        [0.26263232],
#        [0.28174977],
#        [0.30048463],
#        [0.30043365],
#        [0.29834206],
#        [0.29451601],
#        [0.29992347],
#        [0.30654253],
#        [0.31513836],
#        [0.31161839],
#        [0.32770058],
#        [0.33063387],
#        [0.33653873],
#        [0.31109553],
#        [0.30063767],
#        [0.31254945],
#        [0.36125497],
#        [0.37629129],
#        [0.3784594 ],
#        [0.38368829],
#        [0.39380179],
#        [0.38428775],
#        [0.39748756],
#        [0.39886496],
#        [0.40714195],
#        [0.4139778 ],
#        [0.41516386],
#        [0.40645329],
#        [0.41090424],
#        [0.41981891],
#        [0.40869792],
#        [0.38770567],
#        [0.40090549],
#        [0.39524294],
#        [0.4131361 ],
#        [0.41304682],
#        [0.43480424],
#        [0.43442166],
#        [0.42540494],
#        [0.42493307],
#        [0.42838921],
#        [0.41675805],
#        [0.44346383],
#        [0.43588826],
#        [0.4235812 ],
#        [0.43762279],
#        [0.42969009],
#        [0.43243212],
#        [0.41637546],
#        [0.41317432],
#        [0.40090549],
#        [0.41636269],
#        [0.41323815],
#        [0.43428139],
#        [0.42566002],
#        [0.40910596],
#        [0.4141436 ],
#        [0.42221657],
#        [0.42397656],
#        [0.4205714 ],
#        [0.44148705],
#        [0.45643417],
#        [0.45176635],
#        [0.43609236],
#        [0.41240914],
#        [0.41507466],
#        [0.41226888],
#        [0.38889173],
#        [0.37602344],
#        [0.37877824],
#        [0.39442678],
#        [0.36156104],
#        [0.37663566],
#        [0.34998087],
#        [0.36093614],
#        [0.36027293],
#        [0.37061598],
#        [0.39457981],
#        [0.37947966],
#        [0.37969645],
#        [0.35902311],
#        [0.39820175],
#        [0.41484502],
#        [0.42685886],
#        [0.43979082],
#        [0.39957915],
#        [0.37490121],
#        [0.3413978 ],
#        [0.34190789],
#        [0.33790336],
#        [0.34533858],
#        [0.34471367],
#        [0.34538965],
#        [0.35909963],
#        [0.37737531],
#        [0.35893383],
#        [0.3648004 ],
#        [0.37365131],
#        [0.35865321],
#        [0.36325728],
#        [0.3737406 ],
#        [0.3683076 ],
#        [0.35856393],
#        [0.39038387],
#        [0.38695318],
#        [0.37689075],
#        [0.37514345],
#        [0.35292692],
#        [0.35385797],
#        [0.36900903],
#        [0.37763039],
#        [0.39382732],
#        [0.40067593],
#        [0.40109682],
#        [0.4097564 ],
#        [0.41118478],
#        [0.40726946],
#        [0.41587805],
#        [0.41318709],
#        [0.41001149],
#        [0.40654258],
#        [0.40455304],
#        [0.42063515],
#        [0.42375977],
#        [0.41682187],
#        [0.42545593],
#        [0.41965311],
#        [0.4112996 ],
#        [0.4234154 ],
#        [0.41327637],
#        [0.41244737],
#        [0.40998595],
#        [0.41863285],
#        [0.42831269],
#        [0.43275095],
#        [0.43863029],
#        [0.44842495],
#        [0.43384773],
#        [0.4321515 ],
#        [0.43863029],
#        [0.38477239],
#        [0.39043493],
#        [0.36895804],
#        [0.36397147],
#        [0.34305574],
#        [0.34665223],
#        [0.35498021],
#        [0.34736642],
#        [0.35110318],
#        [0.35536287],
#        [0.36871573],
#        [0.37375336],
#        [0.38682568],
#        [0.37556434],
#        [0.3724015 ],
#        [0.36826938],
#        [0.3752455 ],
#        [0.36235175],
#        [0.36437959],
#        [0.35612805],
#        [0.36429031],
#        [0.35860223],
#        [0.37872725],
#        [0.38519319],
#        [0.38370106],
#        [0.397309  ],
#        [0.39890318],
#        [0.39840585],
#        [0.39306214],
#        [0.38233643],
#        [0.37493943],
#        [0.37625307],
#        [0.39135314],
#        [0.39083029],
#        [0.37893127],
#        [0.37726057],
#        [0.37900779],
#        [0.37765592],
#        [0.36752966],
#        [0.34202271],
#        [0.34442037],
#        [0.34792758],
#        [0.34995533],
#        [0.35556689],
#        [0.31772735],
#        [0.31254945],
#        [0.32545596],
#        [0.33046806],
#        [0.3411045 ],
#        [0.3496748 ],
#        [0.34283895],
#        [0.34804231],
#        [0.34586152],
#        [0.3592782 ],
#        [0.37129195],
#        [0.37806404],
#        [0.3741997 ],
#        [0.38225991],
#        [0.38204312],
#        [0.40445099],
#        [0.40471876],
#        [0.40939934],
#        [0.40599411],
#        [0.41220512],
#        [0.4099605 ],
#        [0.4101263 ],
#        [0.41563573],
#        [0.4205714 ],
#        [0.45309276],
#        [0.46533607],
#        [0.46429027],
#        [0.46275984],
#        [0.46063003],
#        [0.47297539],
#        [0.47080728],
#        [0.47367681],
#        [0.47496493],
#        [0.4745951 ],
#        [0.47312842],
#        [0.47173834],
#        [0.4656549 ],
#        [0.4710496 ],
#        [0.46764444],
#        [0.4636909 ],
#        [0.46024744],
#        [0.45978834],
#        [0.45597498],
#        [0.4530417 ],
#        [0.45549035],
#        [0.45880629],
#        [0.45383241],
#        [0.45119243],
#        [0.45316928],
#        [0.46014539],
#        [0.47436555],
#        [0.47432725],
#        [0.46775926],
#        [0.44944521],
#        [0.46263234],
#        [0.44975128],
#        [0.45197045],
#        [0.46570589],
#        [0.46154825],
#        [0.45825791],
#        [0.4638567 ],
#        [0.47055227],
#        [0.48447905],
#        [0.48321647],
#        [0.46751694],
#        [0.47782169],
#        [0.47696723],
#        [0.46750418],
#        [0.46931515],
#        [0.46462188],
#        [0.46769543],
#        [0.46570589],
#        [0.46806533],
#        [0.46504276],
#        [0.48220889],
#        [0.47634232],
#        [0.47914811],
#        [0.46934068],
#        [0.47000381],
#        [0.47286065],
#        [0.49154445],
#        [0.4983676 ],
#        [0.49172301],
#        [0.4948221 ],
#        [0.50971815],
#        [0.5005484 ],
#        [0.49232239],
#        [0.48626449],
#        [0.48908303],
#        [0.47676321],
#        [0.47112612],
#        [0.44936869],
#        [0.4414233 ],
#        [0.44003314],
#        [0.46672623],
#        [0.47941588],
#        [0.47126647],
#        [0.43900011],
#        [0.42810867],
#        [0.40447644],
#        [0.43245757],
#        [0.43860476],
#        [0.44648639],
#        [0.4334906 ],
#        [0.44475194],
#        [0.44500703],
#        [0.43735494],
#        [0.43892359],
#        [0.44601452],
#        [0.45066957],
#        [0.43337586],
#        [0.41864561],
#        [0.41881141],
#        [0.43636013],
#        [0.43375845],
#        [0.45325849],
#        [0.45797729],
#        [0.47618929],
#        [0.47421252],
#        [0.4837011 ],
#        [0.48695323],
#        [0.48409646],
#        [0.47668669],
#        [0.48007908],
#        [0.48352254],
#        [0.47969649],
#        [0.47648259],
#        [0.47408493],
#        [0.47680143],
#        [0.46996559],
#        [0.46781025],
#        [0.45450838]])

# %%
#creating function to create trainX,testX and target(trainY, testY)
def process_data(data , n_features):
    dataX, dataY = [], [] # creating data for dataset and dividing inta X,Y
    for i in range(len(data)-n_features):
        # taking i range from total size- 3
        a = data[i:(i+n_features), 0]
        # Here a is value of data from i to i+ n_features, ie two values and put it in dataX
        dataX.append(a) #putting a in dataX
        #here dataY takes the value of data of i + n_features
        dataY.append(data[i + n_features, 0])
        # putting i+ n_features in  dataY
    return np.array(dataX), np.array(dataY)
# returning dataX and dataY in array

# %%
n_features = 30
# Here we create train X, Train Y and test X, Test Y data where trainX, testX has two value is each block

trainX, trainY = process_data(train, n_features)
print(trainX.shape , trainY.shape)
# Out:
# (1379, 30) (1379,)

# %%
testX, testY = process_data(test, n_features)
print (testX.shape , testY.shape)
# Out:
# (323, 30) (323,)

# %%
stocksX, stocksY = process_data(stocks, n_features)
print (stocksX.shape , stocksY.shape)
# Out:
# (1732, 30) (1732,)

# %%
display (trainX[:10])
# Out:
# array([[0.24318329, 0.23966334, 0.21960214, 0.2015432 , 0.21164394,
#         0.2104834 , 0.19692639, 0.19260299, 0.19612295, 0.18356077,
#         0.19327891, 0.18408365, 0.18736129, 0.14531309, 0.13254687,
#         0.13563321, 0.13522511, 0.12526465, 0.11971687, 0.12364492,
#         0.12122182, 0.1335927 , 0.11568679, 0.12143863, 0.12421889,
#         0.12800666, 0.1254687 , 0.12795565, 0.12377246, 0.13420485],
#        [0.23966334, 0.21960214, 0.2015432 , 0.21164394, 0.2104834 ,
#         0.19692639, 0.19260299, 0.19612295, 0.18356077, 0.19327891,
#         0.18408365, 0.18736129, 0.14531309, 0.13254687, 0.13563321,
#         0.13522511, 0.12526465, 0.11971687, 0.12364492, 0.12122182,
#         0.1335927 , 0.11568679, 0.12143863, 0.12421889, 0.12800666,
#         0.1254687 , 0.12795565, 0.12377246, 0.13420485, 0.13026397],
#        [0.21960214, 0.2015432 , 0.21164394, 0.2104834 , 0.19692639,
#         0.19260299, 0.19612295, 0.18356077, 0.19327891, 0.18408365,
#         0.18736129, 0.14531309, 0.13254687, 0.13563321, 0.13522511,
#         0.12526465, 0.11971687, 0.12364492, 0.12122182, 0.1335927 ,
#         0.11568679, 0.12143863, 0.12421889, 0.12800666, 0.1254687 ,
#         0.12795565, 0.12377246, 0.13420485, 0.13026397, 0.13665354],
#        [0.2015432 , 0.21164394, 0.2104834 , 0.19692639, 0.19260299,
#         0.19612295, 0.18356077, 0.19327891, 0.18408365, 0.18736129,
#         0.14531309, 0.13254687, 0.13563321, 0.13522511, 0.12526465,
#         0.11971687, 0.12364492, 0.12122182, 0.1335927 , 0.11568679,
#         0.12143863, 0.12421889, 0.12800666, 0.1254687 , 0.12795565,
#         0.12377246, 0.13420485, 0.13026397, 0.13665354, 0.13351618],
#        [0.21164394, 0.2104834 , 0.19692639, 0.19260299, 0.19612295,
#         0.18356077, 0.19327891, 0.18408365, 0.18736129, 0.14531309,
#         0.13254687, 0.13563321, 0.13522511, 0.12526465, 0.11971687,
#         0.12364492, 0.12122182, 0.1335927 , 0.11568679, 0.12143863,
#         0.12421889, 0.12800666, 0.1254687 , 0.12795565, 0.12377246,
#         0.13420485, 0.13026397, 0.13665354, 0.13351618, 0.13611783],
#        [0.2104834 , 0.19692639, 0.19260299, 0.19612295, 0.18356077,
#         0.19327891, 0.18408365, 0.18736129, 0.14531309, 0.13254687,
#         0.13563321, 0.13522511, 0.12526465, 0.11971687, 0.12364492,
#         0.12122182, 0.1335927 , 0.11568679, 0.12143863, 0.12421889,
#         0.12800666, 0.1254687 , 0.12795565, 0.12377246, 0.13420485,
#         0.13026397, 0.13665354, 0.13351618, 0.13611783, 0.1262594 ],
#        [0.19692639, 0.19260299, 0.19612295, 0.18356077, 0.19327891,
#         0.18408365, 0.18736129, 0.14531309, 0.13254687, 0.13563321,
#         0.13522511, 0.12526465, 0.11971687, 0.12364492, 0.12122182,
#         0.1335927 , 0.11568679, 0.12143863, 0.12421889, 0.12800666,
#         0.1254687 , 0.12795565, 0.12377246, 0.13420485, 0.13026397,
#         0.13665354, 0.13351618, 0.13611783, 0.1262594 , 0.12166818],
#        [0.19260299, 0.19612295, 0.18356077, 0.19327891, 0.18408365,
#         0.18736129, 0.14531309, 0.13254687, 0.13563321, 0.13522511,
#         0.12526465, 0.11971687, 0.12364492, 0.12122182, 0.1335927 ,
#         0.11568679, 0.12143863, 0.12421889, 0.12800666, 0.1254687 ,
#         0.12795565, 0.12377246, 0.13420485, 0.13026397, 0.13665354,
#         0.13351618, 0.13611783, 0.1262594 , 0.12166818, 0.11524043],
#        [0.19612295, 0.18356077, 0.19327891, 0.18408365, 0.18736129,
#         0.14531309, 0.13254687, 0.13563321, 0.13522511, 0.12526465,
#         0.11971687, 0.12364492, 0.12122182, 0.1335927 , 0.11568679,
#         0.12143863, 0.12421889, 0.12800666, 0.1254687 , 0.12795565,
#         0.12377246, 0.13420485, 0.13026397, 0.13665354, 0.13351618,
#         0.13611783, 0.1262594 , 0.12166818, 0.11524043, 0.1157123 ],
#        [0.18356077, 0.19327891, 0.18408365, 0.18736129, 0.14531309,
#         0.13254687, 0.13563321, 0.13522511, 0.12526465, 0.11971687,
#         0.12364492, 0.12122182, 0.1335927 , 0.11568679, 0.12143863,
#         0.12421889, 0.12800666, 0.1254687 , 0.12795565, 0.12377246,
#         0.13420485, 0.13026397, 0.13665354, 0.13351618, 0.13611783,
#         0.1262594 , 0.12166818, 0.11524043, 0.1157123 , 0.12322407]])

# %%
display (trainY[:10])
# Out:
# array([0.13026397, 0.13665354, 0.13351618, 0.13611783, 0.1262594 ,
#        0.12166818, 0.11524043, 0.1157123 , 0.12322407, 0.13389878])

# %%
# reshaping trainX and testX to use in deep learning model
trainX = trainX.reshape(trainX.shape[0] , 1 ,trainX.shape[1])
display (trainX.shape)
# Out:
# (1379, 1, 30)

# %%
testX = testX.reshape(testX.shape[0] , 1 ,testX.shape[1])
display (testX.shape)
# Out:
# (323, 1, 30)

# %%
stocksX= stocksX.reshape(stocksX.shape[0] , 1 ,stocksX.shape[1])
display (stocksX.shape)
# Out:
# (1732, 1, 30)

# %%
# helps us do mathematical operations
import math
# for setting layers one by one neural layer in model
import tensorflow
from tensorflow import keras
from keras.models import Sequential
# types of layers
from keras.layers import Dense , BatchNormalization , Dropout , Activation
# types of RNN
from keras.layers import LSTM , GRU
#It puts the data in between given range to set data before putting layer
from sklearn.preprocessing import MinMaxScaler
# In this method the errors in column is squared and then mean is found
from sklearn.metrics import mean_squared_error
# Optimizers used
from keras.optimizers import Adam , SGD , RMSprop

# %%
#Checkpointing the model when required and using other call-backs.
filepath="stock_weights1.hdf5"
from keras.callbacks import ReduceLROnPlateau , ModelCheckpoint
# ReduceLROnPlateau- This reduce the learning rate when the matrix stop improving or  too close to reduce overfitting
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.1, epsilon=0.0001, patience=1, verbose=1)
#This check point will stop processing, if the model is not improving.
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='max')
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.

# %%
model = Sequential()
model.add(LSTM(64 , input_shape = (1 , n_features) , return_sequences=True))
model.add(Dropout(0.4))
model.add(LSTM(128,return_sequences=True))
model.add(Dropout(0.4))
model.add(LSTM(128))
model.add(Dropout(0.2))


#model.add(Dense(64 ,  activation = 'relu'))

model.add(Dense(1))
#for getting the details of our models
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 1, 64)             24320
#
#  dropout_3 (Dropout)         (None, 1, 64)             0
#
#  lstm_4 (LSTM)               (None, 1, 128)            98816
#
#  dropout_4 (Dropout)         (None, 1, 128)            0
#
#  lstm_5 (LSTM)               (None, 128)               131584
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 254,849
# Trainable params: 254,849
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Selecting the loss measurement metrics and optimizer for our model, to find out mean square error
model.compile(loss='mean_squared_error', optimizer=Adam(lr = 0.0005) , metrics = ['mean_squared_error'])

# %%
# fitting the data i.e training the trainX, to relate to trainY
# epochs is the times each data in send to fit
# batch size is the size of information send at a time
# validation_data is the validation or data used for testing
history = model.fit(trainX, trainY, epochs=100 , batch_size = 128 ,
          callbacks = [checkpoint , lr_reduce] , validation_data = (testX,testY))
# Out:
# Epoch 1/100
# 11/11 [==============================] - ETA: 0s - loss: 0.1193 - mean_squared_error: 0.1193
# Epoch 1: val_loss improved from -inf to 0.12849, saving model to stock_weights1.hdf5
# 11/11 [==============================] - 16s 280ms/step - loss: 0.1193 - mean_squared_error: 0.1193 - val_loss: 0.1285 - val_mean_squared_error: 0.1285 - lr: 5.0000e-04
# Epoch 2/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0838 - mean_squared_error: 0.0838
# Epoch 2: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0838 - mean_squared_error: 0.0838 - val_loss: 0.0636 - val_mean_squared_error: 0.0636 - lr: 5.0000e-04
# Epoch 3/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0400 - mean_squared_error: 0.0400
# Epoch 3: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0336 - mean_squared_error: 0.0336 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-04
# Epoch 4/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0161 - mean_squared_error: 0.0161
# Epoch 4: val_loss did not improve from 0.12849
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0025 - val_mean_squared_error: 0.0025 - lr: 5.0000e-04
# Epoch 5/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0151 - mean_squared_error: 0.0151
# Epoch 5: val_loss did not improve from 0.12849
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 5.000000237487257e-06.
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - lr: 5.0000e-05
# Epoch 6/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0124 - mean_squared_error: 0.0124
# Epoch 6: val_loss did not improve from 0.12849
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 5.000000328436726e-07.
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - lr: 5.0000e-06
# Epoch 7/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0121 - mean_squared_error: 0.0121
# Epoch 7: val_loss did not improve from 0.12849
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 5.000000555810402e-08.
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-07
# Epoch 8/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0125 - mean_squared_error: 0.0125
# Epoch 8: val_loss did not improve from 0.12849
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-09.
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-08
# Epoch 9/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0121 - mean_squared_error: 0.0121
# Epoch 9: val_loss did not improve from 0.12849
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-10.
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-09
# Epoch 10/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0126 - mean_squared_error: 0.0126
# Epoch 10: val_loss did not improve from 0.12849
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-11.
# 11/11 [==============================] - 0s 44ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-10
# Epoch 11/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0128 - mean_squared_error: 0.0128
# Epoch 11: val_loss did not improve from 0.12849
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-12.
# 11/11 [==============================] - 0s 44ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-11
# Epoch 12/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0126 - mean_squared_error: 0.0126
# Epoch 12: val_loss did not improve from 0.12849
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-13.
# 11/11 [==============================] - 0s 46ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-12
# Epoch 13/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0133 - mean_squared_error: 0.0133
# Epoch 13: val_loss did not improve from 0.12849
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 5.0000005221220725e-14.
# 11/11 [==============================] - 0s 44ms/step - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-13
# Epoch 14/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0121 - mean_squared_error: 0.0121
# Epoch 14: val_loss did not improve from 0.12849
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 5.000000589884709e-15.
# 11/11 [==============================] - 0s 44ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-14
# Epoch 15/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0127 - mean_squared_error: 0.0127
# Epoch 15: val_loss did not improve from 0.12849
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 5.000000759291298e-16.
# 11/11 [==============================] - 0s 44ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-15
# Epoch 16/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0129 - mean_squared_error: 0.0129
# Epoch 16: val_loss did not improve from 0.12849
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 5.000000547533061e-17.
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-16
# Epoch 17/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0132 - mean_squared_error: 0.0132
# Epoch 17: val_loss did not improve from 0.12849
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 5.000000415184163e-18.
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-17
# Epoch 18/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0133 - mean_squared_error: 0.0133
# Epoch 18: val_loss did not improve from 0.12849
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 5.000000332466102e-19.
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-18
# Epoch 19/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0117 - mean_squared_error: 0.0117
# Epoch 19: val_loss did not improve from 0.12849
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 5.000000229068525e-20.
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-19
# Epoch 20/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0121 - mean_squared_error: 0.0121
# Epoch 20: val_loss did not improve from 0.12849
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 5.00000016444504e-21.
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-20
# Epoch 21/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0134 - mean_squared_error: 0.0134
# Epoch 21: val_loss did not improve from 0.12849
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 5.000000245224397e-22.
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-21
# Epoch 22/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0135 - mean_squared_error: 0.0135
# Epoch 22: val_loss did not improve from 0.12849
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 5.0000003461985925e-23.
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-22
# Epoch 23/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0123 - mean_squared_error: 0.0123
# Epoch 23: val_loss did not improve from 0.12849
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 5.000000472416337e-24.
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-23
# Epoch 24/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0120 - mean_squared_error: 0.0120
# Epoch 24: val_loss did not improve from 0.12849
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 5.000000393530247e-25.
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-24
# Epoch 25/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0122 - mean_squared_error: 0.0122
# Epoch 25: val_loss did not improve from 0.12849
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 5.000000590745473e-26.
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-25
# Epoch 26/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0127 - mean_squared_error: 0.0127
# Epoch 26: val_loss did not improve from 0.12849
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 5.000000714004989e-27.
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-26
# Epoch 27/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0137 - mean_squared_error: 0.0137
# Epoch 27: val_loss did not improve from 0.12849
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 5.00000071400499e-28.
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-27
# Epoch 28/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0135 - mean_squared_error: 0.0135
# Epoch 28: val_loss did not improve from 0.12849
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 5.000000617708492e-29.
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-28
# Epoch 29/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0120 - mean_squared_error: 0.0120
# Epoch 29: val_loss did not improve from 0.12849
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 5.0000006177084924e-30.
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-29
# Epoch 30/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0131 - mean_squared_error: 0.0131
# Epoch 30: val_loss did not improve from 0.12849
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 5.0000007681717695e-31.
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-30
# Epoch 31/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0129 - mean_squared_error: 0.0129
# Epoch 31: val_loss did not improve from 0.12849
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 5.000000956250865e-32.
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-31
# Epoch 32/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0122 - mean_squared_error: 0.0122
# Epoch 32: val_loss did not improve from 0.12849
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 5.0000010738003005e-33.
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-32
# Epoch 33/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0141 - mean_squared_error: 0.0141
# Epoch 33: val_loss did not improve from 0.12849
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 5.000001220737094e-34.
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-33
# Epoch 34/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0127 - mean_squared_error: 0.0127
# Epoch 34: val_loss did not improve from 0.12849
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 5.000001037066102e-35.
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-34
# Epoch 35/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0120 - mean_squared_error: 0.0120
# Epoch 35: val_loss did not improve from 0.12849
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 5.000000807477361e-36.
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-35
# Epoch 36/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 36: val_loss did not improve from 0.12849
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 5.000000807477361e-37.
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-36
# Epoch 37/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0122 - mean_squared_error: 0.0122
# Epoch 37: val_loss did not improve from 0.12849
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 5.000000628111158e-38.
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-37
# Epoch 38/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0124 - mean_squared_error: 0.0124
# Epoch 38: val_loss did not improve from 0.12849
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 5.000000516007281e-39.
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-38
# Epoch 39/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0125 - mean_squared_error: 0.0125
# Epoch 39: val_loss did not improve from 0.12849
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 5.000001076526666e-40.
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-39
# Epoch 40/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0123 - mean_squared_error: 0.0123
# Epoch 40: val_loss did not improve from 0.12849
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 5.000001076526667e-41.
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-40
# Epoch 41/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0120 - mean_squared_error: 0.0120
# Epoch 41: val_loss did not improve from 0.12849
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 4.99997305055738e-42.
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-41
# Epoch 42/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0126 - mean_squared_error: 0.0126
# Epoch 42: val_loss did not improve from 0.12849
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 4.9998329207109475e-43.
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 4.9998e-42
# Epoch 43/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0125 - mean_squared_error: 0.0125
# Epoch 43: val_loss did not improve from 0.12849
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 5.002635517639597e-44.
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0026e-43
# Epoch 44/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0129 - mean_squared_error: 0.0129
# Epoch 44: val_loss did not improve from 0.12849
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 5.0446744715693416e-45.
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0447e-44
# Epoch 45/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0114 - mean_squared_error: 0.0114
# Epoch 45: val_loss did not improve from 0.12849
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 5.6051938572992686e-46.
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.6052e-45
# Epoch 46/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0126 - mean_squared_error: 0.0126
# Epoch 46: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 47/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0128 - mean_squared_error: 0.0128
# Epoch 47: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 48/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0126 - mean_squared_error: 0.0126
# Epoch 48: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 49/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0124 - mean_squared_error: 0.0124
# Epoch 49: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 50/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0127 - mean_squared_error: 0.0127
# Epoch 50: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 51/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0124 - mean_squared_error: 0.0124
# Epoch 51: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 52/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0134 - mean_squared_error: 0.0134
# Epoch 52: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 30ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 53/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0119 - mean_squared_error: 0.0119
# Epoch 53: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 45ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 54/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0126 - mean_squared_error: 0.0126
# Epoch 54: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 55/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0122 - mean_squared_error: 0.0122
# Epoch 55: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 56/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0122 - mean_squared_error: 0.0122
# Epoch 56: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 42ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 57/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0129 - mean_squared_error: 0.0129
# Epoch 57: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 58/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0123 - mean_squared_error: 0.0123
# Epoch 58: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 59/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0126 - mean_squared_error: 0.0126
# Epoch 59: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 60/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0122 - mean_squared_error: 0.0122
# Epoch 60: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 61/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0134 - mean_squared_error: 0.0134
# Epoch 61: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 62/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0131 - mean_squared_error: 0.0131
# Epoch 62: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 63/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0138 - mean_squared_error: 0.0138
# Epoch 63: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 64/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 64: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 32ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 65/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0121 - mean_squared_error: 0.0121
# Epoch 65: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 66/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0141 - mean_squared_error: 0.0141
# Epoch 66: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 67/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0113 - mean_squared_error: 0.0113
# Epoch 67: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 68/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 68: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 69/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0134 - mean_squared_error: 0.0134
# Epoch 69: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 70/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0125 - mean_squared_error: 0.0125
# Epoch 70: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 71/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 71: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 72/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0128 - mean_squared_error: 0.0128
# Epoch 72: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 73/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0124 - mean_squared_error: 0.0124
# Epoch 73: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 74/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0128 - mean_squared_error: 0.0128
# Epoch 74: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 75/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0124 - mean_squared_error: 0.0124
# Epoch 75: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 76/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0130 - mean_squared_error: 0.0130
# Epoch 76: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 77/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0122 - mean_squared_error: 0.0122
# Epoch 77: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 78/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0124 - mean_squared_error: 0.0124
# Epoch 78: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 79/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0122 - mean_squared_error: 0.0122
# Epoch 79: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 80/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0122 - mean_squared_error: 0.0122
# Epoch 80: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 81/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 81: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 82/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0125 - mean_squared_error: 0.0125
# Epoch 82: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 83/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0122 - mean_squared_error: 0.0122
# Epoch 83: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 84/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0126 - mean_squared_error: 0.0126
# Epoch 84: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 85/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0121 - mean_squared_error: 0.0121
# Epoch 85: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 86/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0124 - mean_squared_error: 0.0124
# Epoch 86: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 87/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0127 - mean_squared_error: 0.0127
# Epoch 87: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 88/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0127 - mean_squared_error: 0.0127
# Epoch 88: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 89/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0131 - mean_squared_error: 0.0131
# Epoch 89: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 90/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0110 - mean_squared_error: 0.0110
# Epoch 90: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 91/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0134 - mean_squared_error: 0.0134
# Epoch 91: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 92/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 92: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 93/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0122 - mean_squared_error: 0.0122
# Epoch 93: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 94/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0142 - mean_squared_error: 0.0142
# Epoch 94: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 95/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0122 - mean_squared_error: 0.0122
# Epoch 95: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 96/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0125 - mean_squared_error: 0.0125
# Epoch 96: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 97/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0121 - mean_squared_error: 0.0121
# Epoch 97: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 98/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0128 - mean_squared_error: 0.0128
# Epoch 98: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 43ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 99/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0121 - mean_squared_error: 0.0121
# Epoch 99: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 44ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00
# Epoch 100/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0125 - mean_squared_error: 0.0125
# Epoch 100: val_loss did not improve from 0.12849
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 0.0000e+00

# %%
test_pred = model.predict(testX)
display (test_pred [:10])
# Out:
# 11/11 [==============================] - 1s 4ms/step
# array([[0.32829434],
#        [0.32855082],
#        [0.33022392],
#        [0.3300832 ],
#        [0.32745498],
#        [0.32485652],
#        [0.32190374],
#        [0.31928965],
#        [0.31721973],
#        [0.31578204]], dtype=float32)

# %%
test_pred = scaler.inverse_transform(test_pred)
display (test_pred [:10])
# Out:
# array([[693.48553],
#        [693.68665],
#        [694.99854],
#        [694.8882 ],
#        [692.82745],
#        [690.79   ],
#        [688.47473],
#        [686.425  ],
#        [684.80194],
#        [683.6747 ]], dtype=float32)

# %%
testY = testY.reshape(testY.shape[0] , 1)
#Converting reshaped list in 1D array so that it will be efficient in plotting
testY = scaler.inverse_transform(testY)
# taking testY from 1 to 10
display (testY[:10])
# Out:
# array([[653.200012],
#        [653.289978],
#        [654.909973],
#        [640.150024],
#        [624.25    ],
#        [622.609985],
#        [638.369995],
#        [642.      ],
#        [656.98999 ],
#        [671.679993]])

# %%
from sklearn.metrics import r2_score

# %%
# Ploting the graph of stock prices with time
print("Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices")
plt.rcParams["figure.figsize"] = (15,7)
# testY is the blue line
plt.plot(testY , 'b')
# pred is the red line
plt.plot(test_pred , 'r')
# Setting x axis as time
plt.xlabel('Time')
# Setting y axis as stock prices
plt.ylabel('Stock Prices')
# setting title
plt.title('Check the accuracy of the model with time')
# enabling grids in graph
plt.grid(True)
# it call the graph with labels, titles, lines
plt.show()
# Out:
# Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices

# %%
train_pred = model.predict(trainX)
train_pred = scaler.inverse_transform(train_pred)
trainY = trainY.reshape(trainY.shape[0] , 1)
trainY = scaler.inverse_transform(trainY)
print ('Display Accuracy Training Data')
display (r2_score(trainY,train_pred))
# Out:
# 44/44 [==============================] - 0s 4ms/step
# Display Accuracy Training Data
# 0.8078805642947976

# %%
# Ploting the graph of stock prices with time - Training Data
print("Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices")
plt.rcParams["figure.figsize"] = (15,7)
plt.plot(trainY  , 'b')
plt.plot(train_pred, 'r')
plt.xlabel('Time')
plt.ylabel('Stock Prices')
plt.title('Check the accuracy of the model with time')
plt.grid(True)
plt.show()
# Out:
# Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices

# %%
stocks_pred = model.predict(stocksX)
stocks_pred = scaler.inverse_transform(stocks_pred)
stocksY = stocksY.reshape(stocksY.shape[0] , 1)
stocksY = scaler.inverse_transform(stocksY)
print ('Display Accuracy Training Data')
display (r2_score(stocksY,stocks_pred))
# Out:
# 55/55 [==============================] - 0s 4ms/step
# Display Accuracy Training Data
# 0.8130781538115646

# %%
plt.rcParams["figure.figsize"] = (15,7)
plt.plot(stocksY  , 'b')
plt.plot(stocks_pred, 'r')
plt.xlabel('Time')
plt.ylabel('Stock Prices')
plt.title('Check the accuracy of the model with time')
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(stocksY,stocks_pred))
print(mean_squared_error(trainY,train_pred))
print(mean_squared_error(testY,test_pred))
# Out:
# 4934.218454500731
# 5946.65532264453
# 890.8089445752462

# %%
# train and test data
print(r2_score(stocksY,stocks_pred))

#train data
print(r2_score(trainY,train_pred))

#test data
print(r2_score(testY,test_pred))
# Out:
# 0.8130781538115646
# 0.8078805642947976
# 0.501522758031526
